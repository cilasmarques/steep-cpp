# %%
import pandas as pd
from pathlib import Path

# %%
INPUT_DIR = Path('./23-11-26/results-gpu/')
OUTPUT_DIR = './results-outputs'

# %%
# Metrics functions
def get_min_max_mean(df, column, start_time, end_time):
    df_i = df[(df['TIMESTAMP'] >= start_time) & (df['TIMESTAMP'] <= end_time)]
    min_value = df_i[column].min()
    max_value = df_i[column].max()
    mean_value = df_i[column].mean()
    return min_value, max_value, mean_value
  
def add_min_max_mean_columns(df, column, index, min_value, max_value, mean_value):
    df.loc[index, f'{column}_MIN'] = min_value
    df.loc[index, f'{column}_MAX'] = max_value
    df.loc[index, f'{column}_MEAN'] = mean_value

def sumarise_df_cpu(df_cpu, df_mem_cpu, df_timestamp):
    df_cpu['TIMESTAMP'] = df_cpu['TIMESTAMP'].astype(int)
    df_mem_cpu['TIMESTAMP'] = df_mem_cpu['TIMESTAMP'].astype(int)
    df_timestamp['START_TIME'] = df_timestamp['START_TIME'].astype(str).str[:10].astype(int)
    df_timestamp['END_TIME'] = df_timestamp['END_TIME'].astype(str).str[:10].astype(int)
  
    for i, r in df_timestamp.iterrows():
        start_time = r['START_TIME']
        end_time = r['END_TIME']
        
        min_value, max_value, mean_value = get_min_max_mean(df_cpu, ' CPU', start_time, end_time)
        add_min_max_mean_columns(df_timestamp, 'CPU', i, min_value, max_value, mean_value)
        
        min_value, max_value, mean_value = get_min_max_mean(df_mem_cpu, ' USED', start_time, end_time)
        add_min_max_mean_columns(df_timestamp, 'MEM_CPU', i, min_value, max_value, mean_value)
                
    return df_timestamp
  
def sumarise_df_gpu(df_cpu, df_mem_cpu, df_gpu, df_mem_gpu, df_timestamp):
    df_cpu['TIMESTAMP'] = df_cpu['TIMESTAMP'].fillna(0).astype(int)
    df_mem_cpu['TIMESTAMP'] = df_mem_cpu['TIMESTAMP'].fillna(0).astype(int)
    df_gpu['TIMESTAMP'] = df_gpu['TIMESTAMP'].fillna(0).astype(int)
    df_mem_gpu['TIMESTAMP'] = df_mem_gpu['TIMESTAMP'].fillna(0).astype(int)
    df_timestamp['START_TIME'] = df_timestamp['START_TIME'].fillna(0).astype(str).str[:10].astype(int)
    df_timestamp['END_TIME'] = df_timestamp['END_TIME'].fillna(0).astype(str).str[:10].astype(int)

    for i, r in df_timestamp.iterrows():
        start_time = r['START_TIME']
        end_time = r['END_TIME']
        
        min_value, max_value, mean_value = get_min_max_mean(df_cpu, ' CPU', start_time, end_time)
        add_min_max_mean_columns(df_timestamp, 'CPU', i, min_value, max_value, mean_value)
        
        min_value, max_value, mean_value = get_min_max_mean(df_mem_cpu, ' USED', start_time, end_time)
        add_min_max_mean_columns(df_timestamp, 'MEM_CPU', i, min_value, max_value, mean_value)

        min_value, max_value, mean_value = get_min_max_mean(df_gpu, ' GPU', start_time, end_time)
        add_min_max_mean_columns(df_timestamp, 'GPU', i, min_value, max_value, mean_value)
        
        min_value, max_value, mean_value = get_min_max_mean(df_mem_gpu, ' USED', start_time, end_time)
        add_min_max_mean_columns(df_timestamp, 'MEM_GPU', i, min_value, max_value, mean_value)
        
    return df_timestamp

# %%
for dir_path in INPUT_DIR.rglob('**/experiment*'):
    date, device, threads, experiment = str(dir_path).split('/')
    device = device.split('-')[-1]
    threads = threads.split('-')[-1]
    try:
        df_timestamp = pd.read_csv(f'{dir_path}/timestamp.csv')

        if "cpu" in device:
            df_cpu = pd.read_csv(f'{dir_path}/cpu.csv')
            df_mem_cpu = pd.read_csv(f'{dir_path}/mem.csv')
            df_timestamp = sumarise_df_cpu(df_cpu, df_mem_cpu, df_timestamp)

        if "gpu" in device:
            df_cpu = pd.read_csv(f'{dir_path}/cpu.csv')
            df_mem_cpu = pd.read_csv(f'{dir_path}/mem.csv')
            df_gpu = pd.read_csv(f'{dir_path}/gpu.csv')
            df_mem_gpu = pd.read_csv(f'{dir_path}/mem-gpu.csv')
            df_mem_gpu[df_mem_gpu[' COMMAND'].str.contains('/src/main')]
            df_timestamp = sumarise_df_gpu(df_cpu, df_mem_cpu, df_gpu, df_mem_gpu, df_timestamp)

        # multiply the MEM_CPU by 1000 to get the value in MB
        df_timestamp['MEM_CPU_MIN'] = df_timestamp['MEM_CPU_MIN'] * 1000
        df_timestamp['MEM_CPU_MAX'] = df_timestamp['MEM_CPU_MAX'] * 1000
        df_timestamp['MEM_CPU_MEAN'] = df_timestamp['MEM_CPU_MEAN'] * 1000

        df_timestamp.to_csv(f'{dir_path}/timestamp.csv', index=False)

    except Exception as e:
        print(f"Error on {dir}", e)
        pass
# Out:
# Error on <built-in function dir> Error tokenizing data. C error: Expected 7 fields in line 5, saw 465
#
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> [Errno 2] No such file or directory: '23-11-26/results-gpu/results-64t/experiment27/timestamp.csv'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> [Errno 2] No such file or directory: '23-11-26/results-gpu/results-64t/experiment10/timestamp.csv'
# Error on <built-in function dir> [Errno 2] No such file or directory: '23-11-26/results-gpu/results-64t/experiment11/timestamp.csv'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> [Errno 2] No such file or directory: '23-11-26/results-gpu/results-64t/experiment05/timestamp.csv'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> [Errno 2] No such file or directory: '23-11-26/results-gpu/results-64t/experiment30/timestamp.csv'
# Error on <built-in function dir> [Errno 2] No such file or directory: '23-11-26/results-gpu/results-64t/experiment07/timestamp.csv'
# Error on <built-in function dir> invalid literal for int() with base 10: ' main11700998501'
# Error on <built-in function dir> [Errno 2] No such file or directory: '23-11-26/results-gpu/results-64t/experiment04/timestamp.csv'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> [Errno 2] No such file or directory: '23-11-26/results-gpu/results-64t/experiment09/timestamp.csv'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> [Errno 2] No such file or directory: '23-11-26/results-gpu/results-64t/experiment01/timestamp.csv'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> Error tokenizing data. C error: Expected 7 fields in line 24, saw 97
#
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> [Errno 2] No such file or directory: '23-11-26/results-gpu/results-64t/experiment08/timestamp.csv'
# Error on <built-in function dir> [Errno 2] No such file or directory: '23-11-26/results-gpu/results-64t/experiment23/timestamp.csv'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> Error tokenizing data. C error: Expected 7 fields in line 3, saw 73
#
# Error on <built-in function dir> Error tokenizing data. C error: Expected 7 fields in line 12, saw 49
#
# Error on <built-in function dir> [Errno 2] No such file or directory: '23-11-26/results-gpu/results-512t/experiment27/timestamp.csv'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> [Errno 2] No such file or directory: '23-11-26/results-gpu/results-512t/experiment10/timestamp.csv'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> Error tokenizing data. C error: Expected 7 fields in line 12, saw 31
#
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> [Errno 2] No such file or directory: '23-11-26/results-gpu/results-512t/experiment21/timestamp.csv'
# Error on <built-in function dir> Error tokenizing data. C error: Expected 7 fields in line 17, saw 97
#
# Error on <built-in function dir> [Errno 2] No such file or directory: '23-11-26/results-gpu/results-512t/experiment05/timestamp.csv'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> [Errno 2] No such file or directory: '23-11-26/results-gpu/results-512t/experiment03/timestamp.csv'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> [Errno 2] No such file or directory: '23-11-26/results-gpu/results-512t/experiment07/timestamp.csv'
# Error on <built-in function dir> Error tokenizing data. C error: Expected 7 fields in line 7, saw 436
#
# Error on <built-in function dir> [Errno 2] No such file or directory: '23-11-26/results-gpu/results-512t/experiment04/timestamp.csv'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> [Errno 2] No such file or directory: '23-11-26/results-gpu/results-512t/experiment09/timestamp.csv'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> [Errno 2] No such file or directory: '23-11-26/results-gpu/results-512t/experiment01/timestamp.csv'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> [Errno 2] No such file or directory: '23-11-26/results-gpu/results-512t/experiment06/timestamp.csv'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> [Errno 2] No such file or directory: '23-11-26/results-gpu/results-512t/experiment08/timestamp.csv'
# Error on <built-in function dir> [Errno 2] No such file or directory: '23-11-26/results-gpu/results-512t/experiment23/timestamp.csv'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> Error tokenizing data. C error: Expected 4 fields in line 91, saw 7
#
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> [Errno 2] No such file or directory: '23-11-26/results-gpu/results-256t/experiment10/timestamp.csv'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> Error tokenizing data. C error: Expected 7 fields in line 3, saw 19
#
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> [Errno 2] No such file or directory: '23-11-26/results-gpu/results-256t/experiment02/timestamp.csv'
# Error on <built-in function dir> Error tokenizing data. C error: Expected 7 fields in line 17, saw 373
#
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> Error tokenizing data. C error: Expected 7 fields in line 3, saw 114
#
# Error on <built-in function dir> Error tokenizing data. C error: Expected 7 fields in line 7, saw 13
#
# Error on <built-in function dir> Error tokenizing data. C error: Expected 7 fields in line 13, saw 61
#
# Error on <built-in function dir> Error tokenizing data. C error: Expected 7 fields in line 46, saw 13
#
# Error on <built-in function dir> [Errno 2] No such file or directory: '23-11-26/results-gpu/results-256t/experiment04/timestamp.csv'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> [Errno 2] No such file or directory: '23-11-26/results-gpu/results-256t/experiment09/timestamp.csv'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> [Errno 2] No such file or directory: '23-11-26/results-gpu/results-256t/experiment01/timestamp.csv'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> [Errno 2] No such file or directory: '23-11-26/results-gpu/results-256t/experiment06/timestamp.csv'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> Error tokenizing data. C error: Expected 71 fields in line 16, saw 84
#
# Error on <built-in function dir> [Errno 2] No such file or directory: '23-11-26/results-gpu/results-256t/experiment08/timestamp.csv'
# Error on <built-in function dir> Error tokenizing data. C error: Expected 7 fields in line 16, saw 223
#
# Error on <built-in function dir> [Errno 2] No such file or directory: '23-11-26/results-gpu/results-256t/experiment22/timestamp.csv'
# Error on <built-in function dir> Error tokenizing data. C error: Expected 7 fields in line 6, saw 198
#
# Error on <built-in function dir> Error tokenizing data. C error: Expected 7 fields in line 3, saw 127
#
# Error on <built-in function dir> [Errno 2] No such file or directory: '23-11-26/results-gpu/results-02t/experiment27/timestamp.csv'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> [Errno 2] No such file or directory: '23-11-26/results-gpu/results-02t/experiment28/timestamp.csv'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> [Errno 2] No such file or directory: '23-11-26/results-gpu/results-02t/experiment02/timestamp.csv'
# Error on <built-in function dir> [Errno 2] No such file or directory: '23-11-26/results-gpu/results-02t/experiment05/timestamp.csv'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> Error tokenizing data. C error: Expected 4 fields in line 92, saw 9
#
# Error on <built-in function dir> [Errno 2] No such file or directory: '23-11-26/results-gpu/results-02t/experiment30/timestamp.csv'
# Error on <built-in function dir> Error tokenizing data. C error: Expected 7 fields in line 8, saw 55
#
# Error on <built-in function dir> [Errno 2] No such file or directory: '23-11-26/results-gpu/results-02t/experiment24/timestamp.csv'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> [Errno 2] No such file or directory: '23-11-26/results-gpu/results-02t/experiment09/timestamp.csv'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> [Errno 2] No such file or directory: '23-11-26/results-gpu/results-02t/experiment01/timestamp.csv'
# Error on <built-in function dir> Cannot mask with non-boolean array containing NA / NaN values
# Error on <built-in function dir> [Errno 2] No such file or directory: '23-11-26/results-gpu/results-02t/experiment06/timestamp.csv'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> [Errno 2] No such file or directory: '23-11-26/results-gpu/results-02t/experiment26/timestamp.csv'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> Error tokenizing data. C error: Expected 13 fields in line 3, saw 37
#
# Error on <built-in function dir> Error tokenizing data. C error: Expected 7 fields in line 17, saw 273
#
# Error on <built-in function dir> [Errno 2] No such file or directory: '23-11-26/results-gpu/results-128t/experiment25/timestamp.csv'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> [Errno 2] No such file or directory: '23-11-26/results-gpu/results-128t/experiment27/timestamp.csv'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> Error tokenizing data. C error: Expected 7 fields in line 5, saw 435
#
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> [Errno 2] No such file or directory: '23-11-26/results-gpu/results-128t/experiment02/timestamp.csv'
# Error on <built-in function dir> [Errno 2] No such file or directory: '23-11-26/results-gpu/results-128t/experiment05/timestamp.csv'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> Error tokenizing data. C error: Expected 7 fields in line 3, saw 443
#
# Error on <built-in function dir> [Errno 2] No such file or directory: '23-11-26/results-gpu/results-128t/experiment04/timestamp.csv'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> [Errno 2] No such file or directory: '23-11-26/results-gpu/results-128t/experiment09/timestamp.csv'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> [Errno 2] No such file or directory: '23-11-26/results-gpu/results-128t/experiment06/timestamp.csv'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> Error tokenizing data. C error: Expected 7 fields in line 3, saw 19
#
# Error on <built-in function dir> [Errno 2] No such file or directory: '23-11-26/results-gpu/results-128t/experiment08/timestamp.csv'
# Error on <built-in function dir> [Errno 2] No such file or directory: '23-11-26/results-gpu/results-128t/experiment23/timestamp.csv'
# Error on <built-in function dir> Error tokenizing data. C error: Expected 83 fields in line 26, saw 264
#
# Error on <built-in function dir> [Errno 2] No such file or directory: '23-11-26/results-gpu/results-08t/experiment25/timestamp.csv'
# Error on <built-in function dir> [Errno 2] No such file or directory: '23-11-26/results-gpu/results-08t/experiment29/timestamp.csv'
# Error on <built-in function dir> [Errno 2] No such file or directory: '23-11-26/results-gpu/results-08t/experiment27/timestamp.csv'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> [Errno 2] No such file or directory: '23-11-26/results-gpu/results-08t/experiment10/timestamp.csv'
# Error on <built-in function dir> [Errno 2] No such file or directory: '23-11-26/results-gpu/results-08t/experiment11/timestamp.csv'
# Error on <built-in function dir> [Errno 2] No such file or directory: '23-11-26/results-gpu/results-08t/experiment28/timestamp.csv'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> [Errno 2] No such file or directory: '23-11-26/results-gpu/results-08t/experiment02/timestamp.csv'
# Error on <built-in function dir> [Errno 2] No such file or directory: '23-11-26/results-gpu/results-08t/experiment05/timestamp.csv'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> [Errno 2] No such file or directory: '23-11-26/results-gpu/results-08t/experiment03/timestamp.csv'
# Error on <built-in function dir> [Errno 2] No such file or directory: '23-11-26/results-gpu/results-08t/experiment30/timestamp.csv'
# Error on <built-in function dir> [Errno 2] No such file or directory: '23-11-26/results-gpu/results-08t/experiment07/timestamp.csv'
# Error on <built-in function dir> [Errno 2] No such file or directory: '23-11-26/results-gpu/results-08t/experiment24/timestamp.csv'
# Error on <built-in function dir> [Errno 2] No such file or directory: '23-11-26/results-gpu/results-08t/experiment04/timestamp.csv'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> [Errno 2] No such file or directory: '23-11-26/results-gpu/results-08t/experiment09/timestamp.csv'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> [Errno 2] No such file or directory: '23-11-26/results-gpu/results-08t/experiment01/timestamp.csv'
# Error on <built-in function dir> No columns to parse from file
# Error on <built-in function dir> [Errno 2] No such file or directory: '23-11-26/results-gpu/results-08t/experiment06/timestamp.csv'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> [Errno 2] No such file or directory: '23-11-26/results-gpu/results-08t/experiment26/timestamp.csv'
# Error on <built-in function dir> [Errno 2] No such file or directory: '23-11-26/results-gpu/results-08t/experiment08/timestamp.csv'
# Error on <built-in function dir> [Errno 2] No such file or directory: '23-11-26/results-gpu/results-08t/experiment23/timestamp.csv'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> Error tokenizing data. C error: Expected 7 fields in line 3, saw 445
#
# Error on <built-in function dir> [Errno 2] No such file or directory: '23-11-26/results-gpu/results-16t/experiment29/timestamp.csv'
# Error on <built-in function dir> [Errno 2] No such file or directory: '23-11-26/results-gpu/results-16t/experiment27/timestamp.csv'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> [Errno 2] No such file or directory: '23-11-26/results-gpu/results-16t/experiment28/timestamp.csv'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> Error tokenizing data. C error: Expected 7 fields in line 15, saw 37
#
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> Error tokenizing data. C error: Expected 7 fields in line 13, saw 25
#
# Error on <built-in function dir> Error tokenizing data. C error: Expected 7 fields in line 28, saw 323
#
# Error on <built-in function dir> Error tokenizing data. C error: Expected 95 fields in line 8, saw 341
#
# Error on <built-in function dir> [Errno 2] No such file or directory: '23-11-26/results-gpu/results-16t/experiment24/timestamp.csv'
# Error on <built-in function dir> Error tokenizing data. C error: Expected 7 fields in line 3, saw 396
#
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> Error tokenizing data. C error: Expected 7 fields in line 5, saw 238
#
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> Error tokenizing data. C error: Expected 7 fields in line 6, saw 123
#
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> [Errno 2] No such file or directory: '23-11-26/results-gpu/results-16t/experiment26/timestamp.csv'
# Error on <built-in function dir> Error tokenizing data. C error: Expected 7 fields in line 46, saw 220
#
# Error on <built-in function dir> Error tokenizing data. C error: Expected 7 fields in line 27, saw 165
#
# Error on <built-in function dir> Error tokenizing data. C error: Expected 7 fields in line 35, saw 25
#
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> [Errno 2] No such file or directory: '23-11-26/results-gpu/results-1024t/experiment10/timestamp.csv'
# Error on <built-in function dir> [Errno 2] No such file or directory: '23-11-26/results-gpu/results-1024t/experiment11/timestamp.csv'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> Error tokenizing data. C error: Expected 7 fields in line 11, saw 198
#
# Error on <built-in function dir> [Errno 2] No such file or directory: '23-11-26/results-gpu/results-1024t/experiment05/timestamp.csv'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> [Errno 2] No such file or directory: '23-11-26/results-gpu/results-1024t/experiment03/timestamp.csv'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> [Errno 2] No such file or directory: '23-11-26/results-gpu/results-1024t/experiment07/timestamp.csv'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> Error tokenizing data. C error: Expected 13 fields in line 32, saw 122
#
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> [Errno 2] No such file or directory: '23-11-26/results-gpu/results-1024t/experiment09/timestamp.csv'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> [Errno 2] No such file or directory: '23-11-26/results-gpu/results-1024t/experiment01/timestamp.csv'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> [Errno 2] No such file or directory: '23-11-26/results-gpu/results-1024t/experiment06/timestamp.csv'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> Error tokenizing data. C error: Expected 7 fields in line 32, saw 79
#
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> [Errno 2] No such file or directory: '23-11-26/results-gpu/results-32t/experiment25/timestamp.csv'
# Error on <built-in function dir> Error tokenizing data. C error: Expected 7 fields in line 19, saw 351
#
# Error on <built-in function dir> Error tokenizing data. C error: Expected 7 fields in line 5, saw 395
#
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> [Errno 2] No such file or directory: '23-11-26/results-gpu/results-32t/experiment10/timestamp.csv'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> Error tokenizing data. C error: Expected 7 fields in line 68, saw 19
#
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> [Errno 2] No such file or directory: '23-11-26/results-gpu/results-32t/experiment21/timestamp.csv'
# Error on <built-in function dir> [Errno 2] No such file or directory: '23-11-26/results-gpu/results-32t/experiment02/timestamp.csv'
# Error on <built-in function dir> [Errno 2] No such file or directory: '23-11-26/results-gpu/results-32t/experiment05/timestamp.csv'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> [Errno 2] No such file or directory: '23-11-26/results-gpu/results-32t/experiment03/timestamp.csv'
# Error on <built-in function dir> Error tokenizing data. C error: Expected 7 fields in line 18, saw 105
#
# Error on <built-in function dir> [Errno 2] No such file or directory: '23-11-26/results-gpu/results-32t/experiment07/timestamp.csv'
# Error on <built-in function dir> 'START_TIME'
# Error on <built-in function dir> [Errno 2] No such file or directory: '23-11-26/results-gpu/results-32t/experiment04/timestamp.csv'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> [Errno 2] No such file or directory: '23-11-26/results-gpu/results-32t/experiment09/timestamp.csv'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> [Errno 2] No such file or directory: '23-11-26/results-gpu/results-32t/experiment01/timestamp.csv'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> [Errno 2] No such file or directory: '23-11-26/results-gpu/results-32t/experiment06/timestamp.csv'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> Error tokenizing data. C error: Expected 4 fields in line 89, saw 7
#
# Error on <built-in function dir> [Errno 2] No such file or directory: '23-11-26/results-gpu/results-32t/experiment08/timestamp.csv'
# Error on <built-in function dir> Error tokenizing data. C error: Expected 4 fields in line 90, saw 7
#
# Error on <built-in function dir> [Errno 2] No such file or directory: '23-11-26/results-gpu/results-32t/experiment22/timestamp.csv'
# Error on <built-in function dir> Error tokenizing data. C error: Expected 7 fields in line 17, saw 265
#
# Error on <built-in function dir> Error tokenizing data. C error: Expected 7 fields in line 29, saw 291
#
# Error on <built-in function dir> Error tokenizing data. C error: Expected 4 fields in line 87, saw 7
#
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> Error tokenizing data. C error: Expected 4 fields in line 15, saw 226
#
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> [Errno 2] No such file or directory: '23-11-26/results-gpu/results-04t/experiment02/timestamp.csv'
# Error on <built-in function dir> [Errno 2] No such file or directory: '23-11-26/results-gpu/results-04t/experiment05/timestamp.csv'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> [Errno 2] No such file or directory: '23-11-26/results-gpu/results-04t/experiment03/timestamp.csv'
# Error on <built-in function dir> Error tokenizing data. C error: Expected 4 fields in line 15, saw 34
#
# Error on <built-in function dir> Error tokenizing data. C error: Expected 7 fields in line 39, saw 195
#
# Error on <built-in function dir> Error tokenizing data. C error: Expected 7 fields in line 11, saw 273
#
# Error on <built-in function dir> Cannot mask with non-boolean array containing NA / NaN values
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> [Errno 2] No such file or directory: '23-11-26/results-gpu/results-04t/experiment09/timestamp.csv'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> [Errno 2] No such file or directory: '23-11-26/results-gpu/results-04t/experiment01/timestamp.csv'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> Error tokenizing data. C error: Expected 7 fields in line 8, saw 240
#
# Error on <built-in function dir> Error tokenizing data. C error: Expected 7 fields in line 3, saw 97
#
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> Error tokenizing data. C error: Expected 7 fields in line 3, saw 124
#
# Error on <built-in function dir> [Errno 2] No such file or directory: '23-11-26/results-gpu/results-01t/experiment25/timestamp.csv'
# Error on <built-in function dir> [Errno 2] No such file or directory: '23-11-26/results-gpu/results-01t/experiment29/timestamp.csv'
# Error on <built-in function dir> Error tokenizing data. C error: Expected 7 fields in line 3, saw 440
#
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> [Errno 2] No such file or directory: '23-11-26/results-gpu/results-01t/experiment28/timestamp.csv'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> Error tokenizing data. C error: Expected 7 fields in line 73, saw 31
#
# Error on <built-in function dir> [Errno 2] No such file or directory: '23-11-26/results-gpu/results-01t/experiment24/timestamp.csv'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> Error tokenizing data. C error: Expected 7 fields in line 88, saw 38
#
# Error on <built-in function dir> No columns to parse from file
# Error on <built-in function dir> Error tokenizing data. C error: Expected 7 fields in line 56, saw 100
#
# Error on <built-in function dir> Error tokenizing data. C error: Expected 4 fields in line 90, saw 7
#
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> Error tokenizing data. C error: Expected 55 fields in line 25, saw 164
#
# Error on <built-in function dir> Error tokenizing data. C error: Expected 7 fields in line 57, saw 186
#
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> [Errno 2] No such file or directory: '23-11-26/results-gpu/results-20t/experiment11/timestamp.csv'
# Error on <built-in function dir> Error tokenizing data. C error: Expected 7 fields in line 15, saw 49
#
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> [Errno 2] No such file or directory: '23-11-26/results-gpu/results-20t/experiment02/timestamp.csv'
# Error on <built-in function dir> Error tokenizing data. C error: Expected 7 fields in line 3, saw 73
#
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> [Errno 2] No such file or directory: '23-11-26/results-gpu/results-20t/experiment03/timestamp.csv'
# Error on <built-in function dir> Error tokenizing data. C error: Expected 7 fields in line 3, saw 19
#
# Error on <built-in function dir> Error tokenizing data. C error: Expected 7 fields in line 10, saw 19
#
# Error on <built-in function dir> Error tokenizing data. C error: Expected 19 fields in line 4, saw 196
#
# Error on <built-in function dir> [Errno 2] No such file or directory: '23-11-26/results-gpu/results-20t/experiment04/timestamp.csv'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> Error tokenizing data. C error: Expected 7 fields in line 80, saw 73
#
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> [Errno 2] No such file or directory: '23-11-26/results-gpu/results-20t/experiment06/timestamp.csv'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> Error tokenizing data. C error: Expected 7 fields in line 11, saw 19
#
# Error on <built-in function dir> invalid literal for int() with base 10: '0.0'
# Error on <built-in function dir> Error tokenizing data. C error: Expected 4 fields in line 16, saw 22

# %%
df = pd.DataFrame()
for timestamp_file_path in INPUT_DIR.rglob('**/timestamp.csv'):
    date, device, threads, experiment, csv = str(timestamp_file_path).split('/')
    device = device.split('-')[-1]
    threads = threads.split('-')[-1]
    try:
        df_timestamp = pd.read_csv(timestamp_file_path)
        df_timestamp.insert(0, 'directory', timestamp_file_path)
        df_timestamp.insert(1, 'threads', threads.split('-')[-1])
        df_timestamp.insert(2, 'device', device)
        df = pd.concat([df, df_timestamp], axis=0)
    except Exception as e:
        print(f"Error on {dir}", e)
        pass

#keep only the expected columns:
if "cpu" in device:
    df = df[['directory','threads','device',
            'PHASE','TIMESTAMP','START_TIME','END_TIME',
            'CPU_MIN','CPU_MAX','CPU_MEAN','MEM_CPU_MIN',
            'MEM_CPU_MAX','MEM_CPU_MEAN',]]

if "gpu" in device:
    df = df[['directory','threads','device',
            'PHASE','TIMESTAMP','START_TIME','END_TIME',
            'CPU_MIN','CPU_MAX','CPU_MEAN','MEM_CPU_MIN',
            'MEM_CPU_MAX','MEM_CPU_MEAN','GPU_MIN','GPU_MAX',
            'GPU_MEAN','MEM_GPU_MIN','MEM_GPU_MAX','MEM_GPU_MEAN']]

df.sort_values(by=['directory'], inplace=True)
df.reset_index(drop=True, inplace=True)
df.to_csv(f'{OUTPUT_DIR}/{device}.csv', index=False)
# Out:
# Error on <built-in function dir> No columns to parse from file
# Error on <built-in function dir> No columns to parse from file
